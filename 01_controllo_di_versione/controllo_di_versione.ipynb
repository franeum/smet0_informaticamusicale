# %% [markdown]
# # CONTROLLO DI VERSIONE CON `GIT`

# %% [markdown]
# # PROGETTO SOFTWARE

# %% [markdown]
# - costituito da numerosi files (centinaia, a volte migliaia) che cambiano nel tempo

# %% [markdown]
# - creato, gestito, modificato da uno o spesso molti sviluppatori

# %% [markdown]
# # SISTEMA DI VERSIONAMENTO

# %% [markdown]
# - consente di tenere sotto controllo i cambiamenti di un software nel suo complesso e nelle sue parti costitutive

# %% [markdown]
# - permette di gestire l'accesso al progetto (autenticazione, privilegi, permessi di scrittura)

# %% [markdown]
# # GIT

# %% [markdown]
# - Creato da Linus Torvalds, lo stesso del kernel Linux

# %% [markdown]
# - Modello `DISTRIBUITO`

# %% [markdown]
# - Gestione dei dati a `ISTANTANEA` (*snapshot*)

# %% [markdown]
# # DISTRIBUITO

# %% [markdown]
# - Ogni sviluppatore ha una copia locale dell'intero `REPOSITORY`, che contiene tutti i files del progetto, tutte le modifiche e l'`albero delle relazioni`

# %% [markdown]
# - La maggior parte delle operazioni avvengono nella copia locale del repository

# %% [markdown]
# # MODELLO A ISTANTANEA
# - Non registra le modifiche ai file (Modello incrementale, o *a base delta*)
# - crea delle `istantanee` (*snapshot*) di tutti i file in un determinato momento

# %% [markdown]
# ![deltas.png](attachment:deltas.png)

# %% [markdown]
# ![istantanee.png](attachment:istantanee.png)

# %% [markdown]
# # STATI DI UN FILE

# %% [markdown]
# - **Modificato**: il file ha subito dei cambiamenti, ma non è ancora stato *registrato*

# %% [markdown]
# - **In stage**: il file, modificato, viene aggiunto aggiunto allo stage, quindi preparao per essere aggiunto alla prossima *istantanea*

# %% [markdown]
# - **Committato**: il file (insieme agli altri presenti nell'area di stage) viene memorizzato nel repository (database) locale. Viene di fatto salvata una nuova versione (locale) del progetto.

# %% [markdown]
# # AREE DI UN PROGETTO GIT

# %% [markdown]
# * **Directory di lavoro (*working dir*)**: contiene una determinata versione del progetto (scelta attraverso un *checkout*), ossia una certa istantanea dei file su cui vogliamo lavorare

# %% [markdown]
# * **Directory di git (*git dir*)**: database che contiene tutti i dati e i metadati del progetto (storico delle versioni)

# %% [markdown]
# * **Area di stage (*staging area*)**: chiamata Indice (*Index*), contiene le informazioni relative ai cambiamenti dei file che verranno inviati al database per creare una nuova versione

# %% [markdown]
# ![flusso.png](attachment:flusso.png)

# %% [markdown]
# # La directory `.git`

# %% [markdown]
# ## Mantiene in memoria i file, incluse le modifiche e tutte le ramificazioni di un progetto tramite dei `riferimenti` (*puntatori*) ai commit

# %% [markdown]
# ![basic-branching-1.png](attachment:basic-branching-1.png)

# %% [markdown]
# ![gittree.png](attachment:gittree.png)

# %% [markdown]
# # INSTALLAZIONE
# [https://git-scm.com/](https://git-scm.com/)

# %% [markdown]
# # CONFIGURAZIONE MINIMA
# ```bash
# git config --global user.name pippo
# git config --global user.email pippo@example.com
# git config --global core.editor vim
# ```

# %% [markdown]
# # COMANDI ESSENZIALI
# - `git init`: crea un nuovo repository locale
# - `git add`: aggiunge uno o più files all'area di staging
# - `git commit`: salva nella directory `.git` tutto quello che si trova nell'area di staging, creado di fatto una nuova `istantanea` (versione) del progetto
# - `git status`: mostra lo stato dell'area di lavoro

# %% [markdown]
# # ESERCITAZIONE 1
# 1. Creare un nuovo repository chiamato `esercitazione_1`
# 1. Creare un file di testo chiamato `README` e scrivere qualcosa al suo interno
# 1. Aggiungere il file all'area di staging
# 1. Eseguire il commit

# %% [markdown]
# # SVOLGIMENTO
# ```bash
# mkdir esercitazione_1
# cd esercitazione_1
# git init
# echo -e "ciao" >> README
# git add README
# git status
# git commit -m "il mio primo commit"
# git status
# ```

# %% [markdown]
# # REPOSITORY REMOTI SU `GITHUB`
# - Creare un account su [github.com](github.com)
# - Creare un repository su github
# - Clonare un repository in locale con `git clone`
# - Invitare collaboratori

# %% [markdown]
# # COMANDI PRINCIPALI
# - `git push`: invia al repository remoto i commit creati sul repository locale
# - `git pull`: scarica nel repository locale i nuovi commit presenti sul repository remoto
