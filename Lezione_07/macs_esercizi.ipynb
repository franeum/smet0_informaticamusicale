# %% [markdown]
# # Esercizio

# %% [markdown]
# Installare la libreria `librosa` per l'analisi audio con il comando:
# ```bash
# pip install librosa
# ```
#
# potrebbe essere necessario isntallare il pacchetto: `ffmpeg`
#
# Per informazioni sul pacchetto `librosa`:
#
# https://librosa.org/doc/latest/index.html

# %% [markdown]
# # Esercizio

# %% [markdown]
# Importare il file audio `images/break.wav` (campionato a 44100 hz) e determinare il suo tempo in `bpm`, tramite le funzioni del package `librosa`

# %% [markdown]
# # Esercizio

# %% [markdown]
# Disegnare con `matplotlib` la forma d'onda del file importato prima

# %% [markdown]
# # Esercizio

# %% [markdown]
# Sul grafico disegnato nell'esercizio precedente, segnare i `punti di attacco` (onset) riconosciuti tramite la funzione di librosa detect_onset(). La documentazione della funzione si trova qui:
# https://librosa.org/doc/latest/generated/librosa.onset.onset_detect.html#librosa.onset.onset_detect
#
# Per una definizione di `onset`:
# https://it.wikipedia.org/wiki/Onset_(audio)
#
# L'immagine seguente mostra un esempio del risultato:

# %% [markdown]
# ![onset.jpg](attachment:onset.jpg)
